# %% [markdown]
# # MARKET BASKET ANALYSIS ANALYSIS USING: FP-GROWTH MODEL

# %% [markdown]
# ## Problem Statement:
# Implementation of Market Basket Analysis using FP-Growth model on grocery store invoice basket for removing frequent itemsets from the dataset to determine the shopping patterns of a customer.

# %% [markdown]
# ## Details of the Data:
# + DATA SOURCE: Github
# + DATA DICTIONARY: Each row consists of items present in a single customer's basket.

# %% [markdown]
# ## Market Basket Analysis:
# Market Basket Analysis is a modelling technique based upon the theory that if you buy a certain group of items, you are more (or less) likely to buy another group of items. For example, if you are in an English pub and you buy a pint of beer and don't buy a bar meal, you are more likely to buy crisps (US. chips) at the same time than somebody who didn't buy beer.
#
# The set of items a customer buys is referred to as an itemset, and market basket analysis seeks to find relationships between purchases.
#
# Typically the relationship will be in the form of a rule:
#
# IF {beer, no bar meal} THEN {crisps}.
# The probability that a customer will buy beer without a bar meal (i.e. that the antecedent is true) is referred to as the support for the rule. The conditional probability that a customer will purchase crisps is referred to as the confidence.

# %% [markdown]
# ## Algorithm used: FP Growth:
# A FP-tree is a compact data structure that represents the data set in tree form.  Each transaction is read and then mapped onto a path in the FP-tree. This is done until all transactions have been read. Different transactions that have common subsets allow the tree to remain compact because their paths overlap.
#
# The diagram to the right is an example of a best-case scenario that occurs when all transactions have exactly the same itemset; the size of the FP-tree will be only a single branch of nodes.
# The worst case scenario occurs when every transaction has a unique itemset and so the space needed to store the tree is greater than the space used to store the original data set because the FP-tree requires additional space to store pointers between nodes and also the counters for each item. The diagram below is an example of how a worst case scenario FP-tree might appear. As you can see, the complexity of the tree grows with the uniqueness of each transaction.
#
# **Construction**
#
# The construction of a FP-tree is subdivided into three major steps:
#
# 1. Scan the data set to determine the support count of each item, discard the infrequent items and sort the frequent items in decreasing order
#
# 2. Scan the data set one transaction at a time to create the FP-tree. For each transaction:
#
# + If it is a unique transaction form a new path and set the counter for each node to 1.
# + If it shares a common prefix itemset then increment the common itemset node counters and create new nodes if needed.
# + Continue this until each transaction has been mapped unto the tree.
# <img src='./fptree.jpg' />

# %% [markdown]
# ## Exploratory Data Analysis:
# + **Data size** - 9835 rows with 163 unique values
# + **Null value count** - Zero
# + **Number of attributes** - 163 Unique values

# %% [markdown]
# ## Flow of the Program:
# 1. Importing Packages
# 2. Data Pre-processing
# 3. Creation Of Transactions
# 4. Building the model
# 5. Calculation of different metrics

# %% [markdown]
# ## Evaluation of the model:
#
# Association rules analysis is a technique to uncover how items are associated to each other. There are three common ways to measure association.
#
# + Measure 1: Support. This says how popular an itemset is, as measured by the proportion of transactions in which an itemset appears. In Table 1 below, the support of {apple} is 4 out of 8, or 50%. Itemsets can also contain multiple items. For instance, the support of {apple, beer, rice} is 2 out of 8, or 25%.
#
# <img src='1.png' />
#
# If you discover that sales of items beyond a certain proportion tend to have a significant impact on your profits, you might consider using that proportion as your support threshold. You may then identify itemsets with support values above this threshold as significant itemsets.
#
# + Measure 2: Confidence. This says how likely item Y is purchased when item X is purchased, expressed as {X -> Y}. This is measured by the proportion of transactions with item X, in which item Y also appears. In Table 1, the confidence of {apple -> beer} is 3 out of 4, or 75%.
#
# <img src='./2.png' />
#
# One drawback of the confidence measure is that it might misrepresent the importance of an association. This is because it only accounts for how popular apples are, but not beers. If beers are also very popular in general, there will be a higher chance that a transaction containing apples will also contain beers, thus inflating the confidence measure. To account for the base popularity of both constituent items, we use a third measure called lift.
#
# + Measure 3: Lift. This says how likely item Y is purchased when item X is purchased, while controlling for how popular item Y is. In Table 1, the lift of {apple -> beer} is 1,which implies no association between items. A lift value greater than 1 means that item Y is likely to be bought if item X is bought, while a value less than 1 means that item Y is unlikely to be bought if item X is bought.
#
# <img src='./3.png' />
#
# Recall that one drawback of the confidence measure is that it tends to misrepresent the importance of an association. To demonstrate this, we go back to the main dataset to pick 3 association rules containing beer:
#
# <img src='./4.png' />
#
# The {beer -> soda} rule has the highest confidence at 20%. However, both beer and soda appear frequently across all transactions (see Table 3), so their association could simply be a fluke. This is confirmed by the lift value of {beer -> soda}, which is 1, implying no association between beer and soda.
#
# <img src='./5.png' />
#
# On the other hand, the {beer -> male cosmetics} rule has a low confidence, due to few purchases of male cosmetics in general. However, whenever someone does buy male cosmetics, he is very likely to buy beer as well, as inferred from a high lift value of 2.6. The converse is true for {beer -> berries}. With a lift value below 1, we may conclude that if someone buys berries, he would likely be averse to beer.

# %% [markdown]
# ## 1.  Importing packages:

# %%
#importing packages
from pyspark.sql.functions import *
from  pyspark.sql import SQLContext 
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark import SparkContext 
import pyspark.sql.types as typ
from itertools import combinations
import numpy as np
import pandas as pd

# %%
#creating a spark session
spark=SparkSession.builder.appName("Neeha").config(conf=SparkConf()).getOrCreate()

# %% [markdown]
# ## 2. Data preprocessing:

# %%
#importing the fpgrowth model
from pyspark.mllib.fpm import FPGrowth, FPGrowthModel
#importing dataset into rdd
new = sc.textFile("file:////home/dsuser/qlabs/dev_NeehaKhalfay/Market_Basket_Example/groc_comma.txt")
new.take(5)
# Out:
# [u'citrus fruit,semi-finished bread,margarine,ready soups', u'tropical fruit,yogurt,coffee', u'whole milk', u'pip fruit,yogurt,cream cheese ,meat spreads', u'other vegetables,whole milk,condensed milk,long life bakery product']

# %%
#replacing spaces between a single item with a hiphen so that the algorithm may take it as a single item and not 2 items
new2 = new.map(lambda x : x.replace(' ', '-'))

# %%
#replacing a comma with a space to determine that the entire record is a single basket
new3 = new2.map(lambda x : x.replace(',', ' '))

# %%
new3.take(5)
# Out:
# [u'citrus-fruit semi-finished-bread margarine ready-soups', u'tropical-fruit yogurt coffee', u'whole-milk', u'pip-fruit yogurt cream-cheese- meat-spreads', u'other-vegetables whole-milk condensed-milk long-life-bakery-product']

# %% [markdown]
# ## 3. Creation of transactions:

# %%
#Creation of transactions in a specified format for the model to understand from the baskets
transactions = new3.map(lambda line: line.strip().split(' '))
transactions.take(5)
# Out:
# [[u'citrus-fruit', u'semi-finished-bread', u'margarine', u'ready-soups'], [u'tropical-fruit', u'yogurt', u'coffee'], [u'whole-milk'], [u'pip-fruit', u'yogurt', u'cream-cheese-', u'meat-spreads'], [u'other-vegetables', u'whole-milk', u'condensed-milk', u'long-life-bakery-product']]

# %% [markdown]
# ## 4. Building the model:

# %%
#Building the model
model_fp = FPGrowth.train(transactions, minSupport=0.007, numPartitions=10)

# %%
#storing the frequent itemsets in the result and displaying them
result = model_fp.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
# FreqItemset(items=[u'ham'], freq=256)
# FreqItemset(items=[u'ham', u'other-vegetables'], freq=90)
# FreqItemset(items=[u'ham', u'whole-milk'], freq=113)
# FreqItemset(items=[u'liquor'], freq=109)
# FreqItemset(items=[u'frankfurter'], freq=580)
# FreqItemset(items=[u'frankfurter', u'shopping-bags'], freq=81)
# FreqItemset(items=[u'frankfurter', u'rolls/buns'], freq=189)
# FreqItemset(items=[u'frankfurter', u'bottled-water'], freq=72)
# FreqItemset(items=[u'frankfurter', u'yogurt'], freq=110)
# FreqItemset(items=[u'frankfurter', u'tropical-fruit'], freq=93)
# FreqItemset(items=[u'frankfurter', u'pastry'], freq=82)
# FreqItemset(items=[u'frankfurter', u'other-vegetables'], freq=162)
# FreqItemset(items=[u'frankfurter', u'other-vegetables', u'whole-milk'], freq=75)
# FreqItemset(items=[u'frankfurter', u'domestic-eggs'], freq=69)
# FreqItemset(items=[u'frankfurter', u'brown-bread'], freq=70)
# FreqItemset(items=[u'frankfurter', u'sausage'], freq=99)
# FreqItemset(items=[u'frankfurter', u'soda'], freq=111)
# FreqItemset(items=[u'frankfurter', u'pip-fruit'], freq=71)
# FreqItemset(items=[u'frankfurter', u'root-vegetables'], freq=100)
# FreqItemset(items=[u'frankfurter', u'whole-milk'], freq=202)
# FreqItemset(items=[u'liquor-(appetizer)'], freq=78)
# FreqItemset(items=[u'hamburger-meat'], freq=327)
# FreqItemset(items=[u'hamburger-meat', u'rolls/buns'], freq=85)
# FreqItemset(items=[u'hamburger-meat', u'other-vegetables'], freq=136)
# FreqItemset(items=[u'hamburger-meat', u'whole-milk'], freq=145)
# FreqItemset(items=[u'herbs'], freq=160)
# FreqItemset(items=[u'herbs', u'other-vegetables'], freq=76)
# FreqItemset(items=[u'herbs', u'root-vegetables'], freq=69)
# FreqItemset(items=[u'herbs', u'whole-milk'], freq=76)
# FreqItemset(items=[u'pastry'], freq=875)
# FreqItemset(items=[u'pastry', u'shopping-bags'], freq=117)
# FreqItemset(items=[u'pastry', u'rolls/buns'], freq=206)FreqItemset(items=[u'pastry', u'rolls/buns', u'whole-milk'], freq=84)
# FreqItemset(items=[u'pastry', u'bottled-water'], freq=88)
# FreqItemset(items=[u'pastry', u'yogurt'], freq=174)
# FreqItemset(items=[u'pastry', u'yogurt', u'whole-milk'], freq=90)
# FreqItemset(items=[u'pastry', u'tropical-fruit'], freq=130)
# FreqItemset(items=[u'pastry', u'other-vegetables'], freq=222)
# FreqItemset(items=[u'pastry', u'other-vegetables', u'whole-milk'], freq=104)
# FreqItemset(items=[u'pastry', u'sausage'], freq=123)
# FreqItemset(items=[u'pastry', u'soda'], freq=207)
# FreqItemset(items=[u'pastry', u'soda', u'whole-milk'], freq=81)
# FreqItemset(items=[u'pastry', u'root-vegetables'], freq=108)
# FreqItemset(items=[u'pastry', u'whole-milk'], freq=327)
# FreqItemset(items=[u'detergent'], freq=189)
# FreqItemset(items=[u'detergent', u'whole-milk'], freq=88)
# FreqItemset(items=[u'mayonnaise'], freq=90)
# FreqItemset(items=[u'chicken'], freq=422)
# FreqItemset(items=[u'chicken', u'whipped/sour-cream'], freq=71)
# FreqItemset(items=[u'chicken', u'rolls/buns'], freq=95)
# FreqItemset(items=[u'chicken', u'yogurt'], freq=82)
# FreqItemset(items=[u'chicken', u'other-vegetables'], freq=176)
# FreqItemset(items=[u'chicken', u'other-vegetables', u'whole-milk'], freq=83)
# FreqItemset(items=[u'chicken', u'soda'], freq=82)
# FreqItemset(items=[u'chicken', u'root-vegetables'], freq=107)
# FreqItemset(items=[u'chicken', u'whole-milk'], freq=173)
# FreqItemset(items=[u'whole-milk'], freq=2513)
# FreqItemset(items=[u'rice'], freq=75)
# FreqItemset(items=[u'hygiene-articles'], freq=324)
# FreqItemset(items=[u'hygiene-articles', u'yogurt'], freq=72)
# FreqItemset(items=[u'hygiene-articles', u'other-vegetables'], freq=94)
# FreqItemset(items=[u'hygiene-articles', u'soda'], freq=69)
# FreqItemset(items=[u'hygiene-articles', u'whole-milk'], freq=126)
# FreqItemset(items=[u'canned-fish'], freq=148)
# FreqItemset(items=[u'citrus-fruit'], freq=814)
# FreqItemset(items=[u'citrus-fruit', u'shopping-bags'], freq=96)
# FreqItemset(items=[u'citrus-fruit', u'rolls/buns'], freq=165)
# FreqItemset(items=[u'citrus-fruit', u'rolls/buns', u'whole-milk'], freq=71)
# FreqItemset(items=[u'citrus-fruit', u'bottled-water'], freq=133)
# FreqItemset(items=[u'citrus-fruit', u'yogurt'], freq=213)
# FreqItemset(items=[u'citrus-fruit', u'yogurt', u'other-vegetables'], freq=75)
# FreqItemset(items=[u'citrus-fruit', u'yogurt', u'whole-milk'], freq=101)
# FreqItemset(items=[u'citrus-fruit', u'tropical-fruit'], freq=196)
# FreqItemset(items=[u'citrus-fruit', u'tropical-fruit', u'other-vegetables'], freq=89)
# FreqItemset(items=[u'citrus-fruit', u'tropical-fruit', u'whole-milk'], freq=89)
# FreqItemset(items=[u'citrus-fruit', u'other-vegetables'], freq=284)
# FreqItemset(items=[u'citrus-fruit', u'other-vegetables', u'whole-milk'], freq=128)
# FreqItemset(items=[u'citrus-fruit', u'pastry'], freq=96)
# FreqItemset(items=[u'citrus-fruit', u'sausage'], freq=111)
# FreqItemset(items=[u'citrus-fruit', u'soda'], freq=126)
# FreqItemset(items=[u'citrus-fruit', u'root-vegetables'], freq=174)
# FreqItemset(items=[u'citrus-fruit', u'root-vegetables', u'other-vegetables'], freq=102)
# FreqItemset(items=[u'citrus-fruit', u'root-vegetables', u'whole-milk'], freq=90)
# FreqItemset(items=[u'citrus-fruit', u'whole-milk'], freq=300)
# FreqItemset(items=[u'sweet-spreads'], freq=89)
# FreqItemset(items=[u'white-bread'], freq=414)
# FreqItemset(items=[u'white-bread', u'shopping-bags'], freq=73)
# FreqItemset(items=[u'white-bread', u'yogurt'], freq=89)
# FreqItemset(items=[u'white-bread', u'fruit/vegetable-juice'], freq=73)
# FreqItemset(items=[u'white-bread', u'tropical-fruit'], freq=86)
# FreqItemset(items=[u'white-bread', u'other-vegetables'], freq=135)
# FreqItemset(items=[u'white-bread', u'sausage'], freq=71)
# FreqItemset(items=[u'white-bread', u'soda'], freq=101)
# FreqItemset(items=[u'white-bread', u'root-vegetables'], freq=78)
# FreqItemset(items=[u'white-bread', u'whole-milk'], freq=168)
# FreqItemset(items=[u'white-wine'], freq=187)
# FreqItemset(items=[u'other-vegetables'], freq=1903)
# FreqItemset(items=[u'other-vegetables', u'whole-milk'], freq=736)
# FreqItemset(items=[u'canned-vegetables'], freq=106)
# FreqItemset(items=[u'margarine'], freq=576)
# FreqItemset(items=[u'margarine', u'citrus-fruit'], freq=78)
# FreqItemset(items=[u'margarine', u'rolls/buns'], freq=145)
# FreqItemset(items=[u'margarine', u'rolls/buns', u'whole-milk'], freq=78)
# FreqItemset(items=[u'margarine', u'bottled-water'], freq=101)
# FreqItemset(items=[u'margarine', u'yogurt'], freq=140)
# FreqItemset(items=[u'margarine', u'yogurt', u'whole-milk'], freq=69)
# FreqItemset(items=[u'margarine', u'newspapers'], freq=70)
# FreqItemset(items=[u'margarine', u'tropical-fruit'], freq=92)
# FreqItemset(items=[u'margarine', u'other-vegetables'], freq=194)
# FreqItemset(items=[u'margarine', u'other-vegetables', u'whole-milk'], freq=91)
# FreqItemset(items=[u'margarine', u'domestic-eggs'], freq=82)
# FreqItemset(items=[u'margarine', u'sausage'], freq=70)
# FreqItemset(items=[u'margarine', u'soda'], freq=100)
# FreqItemset(items=[u'margarine', u'pip-fruit'], freq=84)
# FreqItemset(items=[u'margarine', u'root-vegetables'], freq=109)
# FreqItemset(items=[u'margarine', u'whole-milk'], freq=238)
# FreqItemset(items=[u'beverages'], freq=256)
# FreqItemset(items=[u'chocolate-marshmallow'], freq=89)
# FreqItemset(items=[u'cream-cheese-'], freq=390)
# FreqItemset(items=[u'cream-cheese-', u'rolls/buns'], freq=98)
# FreqItemset(items=[u'cream-cheese-', u'yogurt'], freq=122)
# FreqItemset(items=[u'cream-cheese-', u'tropical-fruit'], freq=71)
# FreqItemset(items=[u'cream-cheese-', u'other-vegetables'], freq=135)
# FreqItemset(items=[u'cream-cheese-', u'root-vegetables'], freq=74)
# FreqItemset(items=[u'cream-cheese-', u'whole-milk'], freq=162)
# FreqItemset(items=[u'pickled-vegetables'], freq=176)
# FreqItemset(items=[u'pickled-vegetables', u'whole-milk'], freq=70)
# FreqItemset(items=[u'rolls/buns'], freq=1809)
# FreqItemset(items=[u'rolls/buns', u'other-vegetables'], freq=419)
# FreqItemset(items=[u'rolls/buns', u'other-vegetables', u'whole-milk'], freq=176)
# FreqItemset(items=[u'rolls/buns', u'whole-milk'], freq=557)
# FreqItemset(items=[u'salt'], freq=106)
# FreqItemset(items=[u'coffee'], freq=571)
# FreqItemset(items=[u'coffee', u'shopping-bags'], freq=92)
# FreqItemset(items=[u'coffee', u'rolls/buns'], freq=108)
# FreqItemset(items=[u'coffee', u'bottled-water'], freq=72)
# FreqItemset(items=[u'coffee', u'yogurt'], freq=96)
# FreqItemset(items=[u'coffee', u'tropical-fruit'], freq=70)
# FreqItemset(items=[u'coffee', u'other-vegetables'], freq=132)
# FreqItemset(items=[u'coffee', u'soda'], freq=98)
# FreqItemset(items=[u'coffee', u'root-vegetables'], freq=72)
# FreqItemset(items=[u'coffee', u'whole-milk'], freq=184)
# FreqItemset(items=[u'meat'], freq=254)
# FreqItemset(items=[u'meat', u'other-vegetables'], freq=98)
# FreqItemset(items=[u'meat', u'whole-milk'], freq=98)
# FreqItemset(items=[u'pasta'], freq=148)
# FreqItemset(items=[u'bottled-beer'], freq=792)
# FreqItemset(items=[u'bottled-beer', u'rolls/buns'], freq=134)
# FreqItemset(items=[u'bottled-beer', u'bottled-water'], freq=155)
# FreqItemset(items=[u'bottled-beer', u'yogurt'], freq=91)
# FreqItemset(items=[u'bottled-beer', u'tropical-fruit'], freq=81)
# FreqItemset(items=[u'bottled-beer', u'other-vegetables'], freq=159)
# FreqItemset(items=[u'bottled-beer', u'other-vegetables', u'whole-milk'], freq=75)
# FreqItemset(items=[u'bottled-beer', u'sausage'], freq=77)
# FreqItemset(items=[u'bottled-beer', u'soda'], freq=167)
# FreqItemset(items=[u'bottled-beer', u'root-vegetables'], freq=95)
# FreqItemset(items=[u'bottled-beer', u'whole-milk'], freq=201)
# FreqItemset(items=[u'instant-coffee'], freq=73)
# FreqItemset(items=[u'onions'], freq=305)
# FreqItemset(items=[u'onions', u'yogurt'], freq=71)
# FreqItemset(items=[u'onions', u'other-vegetables'], freq=140)
# FreqItemset(items=[u'onions', u'root-vegetables'], freq=93)
# FreqItemset(items=[u'onions', u'whole-milk'], freq=119)
# FreqItemset(items=[u'frozen-dessert'], freq=106)
# FreqItemset(items=[u'pork'], freq=567)
# FreqItemset(items=[u'pork', u'whipped/sour-cream'], freq=81)
# FreqItemset(items=[u'pork', u'rolls/buns'], freq=111)
# FreqItemset(items=[u'pork', u'bottled-water'], freq=73)
# FreqItemset(items=[u'pork', u'yogurt'], freq=94)
# FreqItemset(items=[u'pork', u'tropical-fruit'], freq=84)
# FreqItemset(items=[u'pork', u'other-vegetables'], freq=213)
# FreqItemset(items=[u'pork', u'other-vegetables', u'whole-milk'], freq=100)
# FreqItemset(items=[u'pork', u'soda'], freq=117)
# FreqItemset(items=[u'pork', u'root-vegetables'], freq=134)
# FreqItemset(items=[u'pork', u'root-vegetables', u'other-vegetables'], freq=69)
# FreqItemset(items=[u'pork', u'whole-milk'], freq=218)
# FreqItemset(items=[u'ice-cream'], freq=246)
# FreqItemset(items=[u'seasonal-products'], freq=140)
# FreqItemset(items=[u'newspapers'], freq=785)
# FreqItemset(items=[u'newspapers', u'citrus-fruit'], freq=82)
# FreqItemset(items=[u'newspapers', u'rolls/buns'], freq=194)
# FreqItemset(items=[u'newspapers', u'rolls/buns', u'whole-milk'], freq=75)
# FreqItemset(items=[u'newspapers', u'bottled-water'], freq=111)
# FreqItemset(items=[u'newspapers', u'yogurt'], freq=151)
# FreqItemset(items=[u'newspapers', u'tropical-fruit'], freq=116)
# FreqItemset(items=[u'newspapers', u'pastry'], freq=83)
# FreqItemset(items=[u'newspapers', u'other-vegetables'], freq=190)
# FreqItemset(items=[u'newspapers', u'other-vegetables', u'whole-milk'], freq=82)
# FreqItemset(items=[u'newspapers', u'sausage'], freq=79)
# FreqItemset(items=[u'newspapers', u'soda'], freq=144)
# FreqItemset(items=[u'newspapers', u'root-vegetables'], freq=113)
# FreqItemset(items=[u'newspapers', u'whole-milk'], freq=269)
# FreqItemset(items=[u'popcorn'], freq=71)
# FreqItemset(items=[u'specialty-chocolate'], freq=299)
# FreqItemset(items=[u'specialty-chocolate', u'whole-milk'], freq=79)
# FreqItemset(items=[u'baking-powder'], freq=174)
# FreqItemset(items=[u'baking-powder', u'other-vegetables'], freq=72)
# FreqItemset(items=[u'baking-powder', u'whole-milk'], freq=91)
# FreqItemset(items=[u'soda'], freq=1715)
# FreqItemset(items=[u'soda', u'rolls/buns'], freq=377)
# FreqItemset(items=[u'soda', u'rolls/buns', u'other-vegetables'], freq=97)
# FreqItemset(items=[u'soda', u'rolls/buns', u'whole-milk'], freq=87)
# FreqItemset(items=[u'soda', u'other-vegetables'], freq=322)
# FreqItemset(items=[u'soda', u'other-vegetables', u'whole-milk'], freq=137)
# FreqItemset(items=[u'soda', u'whole-milk'], freq=394)
# FreqItemset(items=[u'candles'], freq=88)
# FreqItemset(items=[u'waffles'], freq=378)
# FreqItemset(items=[u'waffles', u'rolls/buns'], freq=90)
# FreqItemset(items=[u'waffles', u'yogurt'], freq=74)
# FreqItemset(items=[u'waffles', u'pastry'], freq=69)
# FreqItemset(items=[u'waffles', u'other-vegetables'], freq=99)
# FreqItemset(items=[u'waffles', u'soda'], freq=94)
# FreqItemset(items=[u'waffles', u'whole-milk'], freq=125)
# FreqItemset(items=[u'candy'], freq=294)
# FreqItemset(items=[u'candy', u'rolls/buns'], freq=70)
# FreqItemset(items=[u'candy', u'soda'], freq=85)
# FreqItemset(items=[u'candy', u'whole-milk'], freq=81)
# FreqItemset(items=[u'cake-bar'], freq=130)
# FreqItemset(items=[u'canned-beer'], freq=764)
# FreqItemset(items=[u'canned-beer', u'shopping-bags'], freq=112)
# FreqItemset(items=[u'canned-beer', u'rolls/buns'], freq=111)
# FreqItemset(items=[u'canned-beer', u'bottled-water'], freq=79)
# FreqItemset(items=[u'canned-beer', u'other-vegetables'], freq=89)
# FreqItemset(items=[u'canned-beer', u'soda'], freq=136)
# FreqItemset(items=[u'canned-beer', u'whole-milk'], freq=87)
# FreqItemset(items=[u'semi-finished-bread'], freq=174)
# FreqItemset(items=[u'semi-finished-bread', u'whole-milk'], freq=70)
# FreqItemset(items=[u'specialty-cheese'], freq=84)
# FreqItemset(items=[u'yogurt'], freq=1372)
# FreqItemset(items=[u'yogurt', u'rolls/buns'], freq=338)
# FreqItemset(items=[u'yogurt', u'rolls/buns', u'other-vegetables'], freq=113)
# FreqItemset(items=[u'yogurt', u'rolls/buns', u'whole-milk'], freq=153)
# FreqItemset(items=[u'yogurt', u'other-vegetables'], freq=427)
# FreqItemset(items=[u'yogurt', u'other-vegetables', u'whole-milk'], freq=219)
# FreqItemset(items=[u'yogurt', u'soda'], freq=269)
# FreqItemset(items=[u'yogurt', u'soda', u'rolls/buns'], freq=85)
# FreqItemset(items=[u'yogurt', u'soda', u'other-vegetables'], freq=82)
# FreqItemset(items=[u'yogurt', u'soda', u'whole-milk'], freq=103)
# FreqItemset(items=[u'yogurt', u'whole-milk'], freq=551)
# FreqItemset(items=[u'salty-snack'], freq=372)
# FreqItemset(items=[u'salty-snack', u'other-vegetables'], freq=106)
# FreqItemset(items=[u'salty-snack', u'soda'], freq=92)
# FreqItemset(items=[u'salty-snack', u'whole-milk'], freq=110)
# FreqItemset(items=[u'sliced-cheese'], freq=241)
# FreqItemset(items=[u'sliced-cheese', u'rolls/buns'], freq=75)
# FreqItemset(items=[u'sliced-cheese', u'yogurt'], freq=79)
# FreqItemset(items=[u'sliced-cheese', u'other-vegetables'], freq=89)
# FreqItemset(items=[u'sliced-cheese', u'sausage'], freq=69)
# FreqItemset(items=[u'sliced-cheese', u'whole-milk'], freq=106)
# FreqItemset(items=[u'dish-cleaner'], freq=103)
# FreqItemset(items=[u'butter'], freq=545)
# FreqItemset(items=[u'butter', u'whipped/sour-cream'], freq=100)
# FreqItemset(items=[u'butter', u'citrus-fruit'], freq=90)
# FreqItemset(items=[u'butter', u'rolls/buns'], freq=132)
# FreqItemset(items=[u'butter', u'bottled-water'], freq=88)
# FreqItemset(items=[u'butter', u'yogurt'], freq=144)
# FreqItemset(items=[u'butter', u'yogurt', u'whole-milk'], freq=92)
# FreqItemset(items=[u'butter', u'tropical-fruit'], freq=98)
# FreqItemset(items=[u'butter', u'fruit/vegetable-juice'], freq=79)
# FreqItemset(items=[u'butter', u'pastry'], freq=75)
# FreqItemset(items=[u'butter', u'other-vegetables'], freq=197)
# FreqItemset(items=[u'butter', u'other-vegetables', u'whole-milk'], freq=113)
# FreqItemset(items=[u'butter', u'domestic-eggs'], freq=95)
# FreqItemset(items=[u'butter', u'sausage'], freq=85)
# FreqItemset(items=[u'butter', u'soda'], freq=87)
# FreqItemset(items=[u'butter', u'pip-fruit'], freq=72)
# FreqItemset(items=[u'butter', u'root-vegetables'], freq=127)
# FreqItemset(items=[u'butter', u'root-vegetables', u'whole-milk'], freq=81)
# FreqItemset(items=[u'butter', u'whole-milk'], freq=271)
# FreqItemset(items=[u'dog-food'], freq=84)
# FreqItemset(items=[u'long-life-bakery-product'], freq=368)
# FreqItemset(items=[u'long-life-bakery-product', u'rolls/buns'], freq=78)
# FreqItemset(items=[u'long-life-bakery-product', u'yogurt'], freq=86)
# FreqItemset(items=[u'long-life-bakery-product', u'other-vegetables'], freq=105)
# FreqItemset(items=[u'long-life-bakery-product', u'soda'], freq=75)
# FreqItemset(items=[u'long-life-bakery-product', u'whole-milk'], freq=133)
# FreqItemset(items=[u'dishes'], freq=173)
# FreqItemset(items=[u'bottled-water'], freq=1087)
# FreqItemset(items=[u'bottled-water', u'rolls/buns'], freq=238)
# FreqItemset(items=[u'bottled-water', u'rolls/buns', u'other-vegetables'], freq=72)
# FreqItemset(items=[u'bottled-water', u'rolls/buns', u'whole-milk'], freq=86)
# FreqItemset(items=[u'bottled-water', u'yogurt'], freq=226)
# FreqItemset(items=[u'bottled-water', u'yogurt', u'rolls/buns'], freq=70)
# FreqItemset(items=[u'bottled-water', u'yogurt', u'other-vegetables'], freq=80)
# FreqItemset(items=[u'bottled-water', u'yogurt', u'soda'], freq=73)
# FreqItemset(items=[u'bottled-water', u'yogurt', u'whole-milk'], freq=95)
# FreqItemset(items=[u'bottled-water', u'other-vegetables'], freq=244)
# FreqItemset(items=[u'bottled-water', u'other-vegetables', u'whole-milk'], freq=106)
# FreqItemset(items=[u'bottled-water', u'soda'], freq=285)
# FreqItemset(items=[u'bottled-water', u'soda', u'whole-milk'], freq=74)
# FreqItemset(items=[u'bottled-water', u'whole-milk'], freq=338)
# FreqItemset(items=[u'hard-cheese'], freq=241)
# FreqItemset(items=[u'hard-cheese', u'other-vegetables'], freq=93)
# FreqItemset(items=[u'hard-cheese', u'whole-milk'], freq=99)
# FreqItemset(items=[u'flower-(seeds)'], freq=102)
# FreqItemset(items=[u'curd'], freq=524)
# FreqItemset(items=[u'curd', u'whipped/sour-cream'], freq=103)
# FreqItemset(items=[u'curd', u'citrus-fruit'], freq=70)
# FreqItemset(items=[u'curd', u'rolls/buns'], freq=99)
# FreqItemset(items=[u'curd', u'yogurt'], freq=170)
# FreqItemset(items=[u'curd', u'yogurt', u'whole-milk'], freq=99)
# FreqItemset(items=[u'curd', u'tropical-fruit'], freq=101)
# FreqItemset(items=[u'curd', u'pastry'], freq=74)
# FreqItemset(items=[u'curd', u'other-vegetables'], freq=169)
# FreqItemset(items=[u'curd', u'other-vegetables', u'whole-milk'], freq=97)
# FreqItemset(items=[u'curd', u'sausage'], freq=75)
# FreqItemset(items=[u'curd', u'soda'], freq=80)
# FreqItemset(items=[u'curd', u'pip-fruit'], freq=77)
# FreqItemset(items=[u'curd', u'root-vegetables'], freq=107)
# FreqItemset(items=[u'curd', u'whole-milk'], freq=257)
# FreqItemset(items=[u'misc.-beverages'], freq=279)
# FreqItemset(items=[u'misc.-beverages', u'soda'], freq=72)
# FreqItemset(items=[u'misc.-beverages', u'whole-milk'], freq=69)
# FreqItemset(items=[u'packaged-fruit/vegetables'], freq=128)
# FreqItemset(items=[u'pip-fruit'], freq=744)
# FreqItemset(items=[u'pip-fruit', u'shopping-bags'], freq=92)
# FreqItemset(items=[u'pip-fruit', u'citrus-fruit'], freq=136)
# FreqItemset(items=[u'pip-fruit', u'rolls/buns'], freq=137)
# FreqItemset(items=[u'pip-fruit', u'bottled-water'], freq=104)
# FreqItemset(items=[u'pip-fruit', u'yogurt'], freq=177)
# FreqItemset(items=[u'pip-fruit', u'yogurt', u'other-vegetables'], freq=80)
# FreqItemset(items=[u'pip-fruit', u'yogurt', u'whole-milk'], freq=94)
# FreqItemset(items=[u'pip-fruit', u'tropical-fruit'], freq=201)
# FreqItemset(items=[u'pip-fruit', u'tropical-fruit', u'other-vegetables'], freq=93)
# FreqItemset(items=[u'pip-fruit', u'tropical-fruit', u'whole-milk'], freq=83)
# FreqItemset(items=[u'pip-fruit', u'other-vegetables'], freq=257)
# FreqItemset(items=[u'pip-fruit', u'other-vegetables', u'whole-milk'], freq=133)
# FreqItemset(items=[u'pip-fruit', u'pastry'], freq=105)
# FreqItemset(items=[u'pip-fruit', u'sausage'], freq=106)
# FreqItemset(items=[u'pip-fruit', u'soda'], freq=131)
# FreqItemset(items=[u'pip-fruit', u'root-vegetables'], freq=153)
# FreqItemset(items=[u'pip-fruit', u'root-vegetables', u'other-vegetables'], freq=80)
# FreqItemset(items=[u'pip-fruit', u'root-vegetables', u'whole-milk'], freq=88)
# FreqItemset(items=[u'pip-fruit', u'whole-milk'], freq=296)
# FreqItemset(items=[u'condensed-milk'], freq=101)
# FreqItemset(items=[u'beef'], freq=516)
# FreqItemset(items=[u'beef', u'pork'], freq=75)
# FreqItemset(items=[u'beef', u'citrus-fruit'], freq=83)
# FreqItemset(items=[u'beef', u'rolls/buns'], freq=134)
# FreqItemset(items=[u'beef', u'yogurt'], freq=115)
# FreqItemset(items=[u'beef', u'tropical-fruit'], freq=75)
# FreqItemset(items=[u'beef', u'other-vegetables'], freq=194)
# FreqItemset(items=[u'beef', u'other-vegetables', u'whole-milk'], freq=91)
# FreqItemset(items=[u'beef', u'soda'], freq=80)
# FreqItemset(items=[u'beef', u'root-vegetables'], freq=171)
# FreqItemset(items=[u'beef', u'root-vegetables', u'other-vegetables'], freq=78)
# FreqItemset(items=[u'beef', u'root-vegetables', u'whole-milk'], freq=79)
# FreqItemset(items=[u'beef', u'whole-milk'], freq=209)
# FreqItemset(items=[u'cat-food'], freq=229)
# FreqItemset(items=[u'cat-food', u'whole-milk'], freq=87)
# FreqItemset(items=[u'frozen-meals'], freq=279)
# FreqItemset(items=[u'frozen-meals', u'other-vegetables'], freq=74)
# FreqItemset(items=[u'frozen-meals', u'whole-milk'], freq=97)
# FreqItemset(items=[u'mustard'], freq=118)
# FreqItemset(items=[u'fruit/vegetable-juice'], freq=711)
# FreqItemset(items=[u'fruit/vegetable-juice', u'shopping-bags'], freq=105)
# FreqItemset(items=[u'fruit/vegetable-juice', u'citrus-fruit'], freq=102)
# FreqItemset(items=[u'fruit/vegetable-juice', u'rolls/buns'], freq=143)
# FreqItemset(items=[u'fruit/vegetable-juice', u'bottled-water'], freq=140)
# FreqItemset(items=[u'fruit/vegetable-juice', u'newspapers'], freq=81)
# FreqItemset(items=[u'fruit/vegetable-juice', u'yogurt'], freq=184)
# FreqItemset(items=[u'fruit/vegetable-juice', u'yogurt', u'other-vegetables'], freq=81)
# FreqItemset(items=[u'fruit/vegetable-juice', u'yogurt', u'whole-milk'], freq=93)
# FreqItemset(items=[u'fruit/vegetable-juice', u'tropical-fruit'], freq=135)
# FreqItemset(items=[u'fruit/vegetable-juice', u'pastry'], freq=84)
# FreqItemset(items=[u'fruit/vegetable-juice', u'other-vegetables'], freq=207)
# FreqItemset(items=[u'fruit/vegetable-juice', u'other-vegetables', u'whole-milk'], freq=103)
# FreqItemset(items=[u'fruit/vegetable-juice', u'sausage'], freq=99)
# FreqItemset(items=[u'fruit/vegetable-juice', u'soda'], freq=181)
# FreqItemset(items=[u'fruit/vegetable-juice', u'bottled-beer'], freq=69)
# FreqItemset(items=[u'fruit/vegetable-juice', u'pip-fruit'], freq=94)
# FreqItemset(items=[u'fruit/vegetable-juice', u'root-vegetables'], freq=118)
# FreqItemset(items=[u'fruit/vegetable-juice', u'whole-milk'], freq=262)
# FreqItemset(items=[u'frozen-potato-products'], freq=83)
# FreqItemset(items=[u'dessert'], freq=365)
# FreqItemset(items=[u'dessert', u'yogurt'], freq=97)
# FreqItemset(items=[u'dessert', u'other-vegetables'], freq=114)
# FreqItemset(items=[u'dessert', u'soda'], freq=97)
# FreqItemset(items=[u'dessert', u'whole-milk'], freq=135)
# FreqItemset(items=[u'flour'], freq=171)
# FreqItemset(items=[u'flour', u'whole-milk'], freq=83)
# FreqItemset(items=[u'root-vegetables'], freq=1072)
# FreqItemset(items=[u'root-vegetables', u'rolls/buns'], freq=239)
# FreqItemset(items=[u'root-vegetables', u'rolls/buns', u'other-vegetables'], freq=120)
# FreqItemset(items=[u'root-vegetables', u'rolls/buns', u'whole-milk'], freq=125)
# FreqItemset(items=[u'root-vegetables', u'bottled-water'], freq=154)
# FreqItemset(items=[u'root-vegetables', u'bottled-water', u'other-vegetables'], freq=69)
# FreqItemset(items=[u'root-vegetables', u'bottled-water', u'whole-milk'], freq=72)
# FreqItemset(items=[u'root-vegetables', u'yogurt'], freq=254)
# FreqItemset(items=[u'root-vegetables', u'yogurt', u'rolls/buns'], freq=71)
# FreqItemset(items=[u'root-vegetables', u'yogurt', u'other-vegetables'], freq=127)
# FreqItemset(items=[u'root-vegetables', u'yogurt', u'other-vegetables', u'whole-milk'], freq=77)
# FreqItemset(items=[u'root-vegetables', u'yogurt', u'whole-milk'], freq=143)
# FreqItemset(items=[u'root-vegetables', u'other-vegetables'], freq=466)
# FreqItemset(items=[u'root-vegetables', u'other-vegetables', u'whole-milk'], freq=228)
# FreqItemset(items=[u'root-vegetables', u'soda'], freq=183)
# FreqItemset(items=[u'root-vegetables', u'soda', u'other-vegetables'], freq=81)
# FreqItemset(items=[u'root-vegetables', u'soda', u'whole-milk'], freq=80)
# FreqItemset(items=[u'root-vegetables', u'whole-milk'], freq=481)
# FreqItemset(items=[u'frozen-fish'], freq=115)
# FreqItemset(items=[u'whipped/sour-cream'], freq=705)
# FreqItemset(items=[u'whipped/sour-cream', u'shopping-bags'], freq=78)
# FreqItemset(items=[u'whipped/sour-cream', u'citrus-fruit'], freq=107)
# FreqItemset(items=[u'whipped/sour-cream', u'rolls/buns'], freq=144)
# FreqItemset(items=[u'whipped/sour-cream', u'rolls/buns', u'whole-milk'], freq=77)
# FreqItemset(items=[u'whipped/sour-cream', u'bottled-water'], freq=86)
# FreqItemset(items=[u'whipped/sour-cream', u'newspapers'], freq=71)
# FreqItemset(items=[u'whipped/sour-cream', u'yogurt'], freq=204)
# FreqItemset(items=[u'whipped/sour-cream', u'yogurt', u'other-vegetables'], freq=100)
# FreqItemset(items=[u'whipped/sour-cream', u'yogurt', u'whole-milk'], freq=107)
# FreqItemset(items=[u'whipped/sour-cream', u'tropical-fruit'], freq=136)
# FreqItemset(items=[u'whipped/sour-cream', u'tropical-fruit', u'other-vegetables'], freq=77)
# FreqItemset(items=[u'whipped/sour-cream', u'tropical-fruit', u'whole-milk'], freq=78)
# FreqItemset(items=[u'whipped/sour-cream', u'fruit/vegetable-juice'], freq=89)
# FreqItemset(items=[u'whipped/sour-cream', u'pastry'], freq=74)
# FreqItemset(items=[u'whipped/sour-cream', u'other-vegetables'], freq=284)
# FreqItemset(items=[u'whipped/sour-cream', u'other-vegetables', u'whole-milk'], freq=144)
# FreqItemset(items=[u'whipped/sour-cream', u'sausage'], freq=89)
# FreqItemset(items=[u'whipped/sour-cream', u'soda'], freq=114)
# FreqItemset(items=[u'whipped/sour-cream', u'root-vegetables'], freq=168)
# FreqItemset(items=[u'whipped/sour-cream', u'root-vegetables', u'other-vegetables'], freq=84)
# FreqItemset(items=[u'whipped/sour-cream', u'root-vegetables', u'whole-milk'], freq=93)
# FreqItemset(items=[u'whipped/sour-cream', u'pip-fruit'], freq=91)
# FreqItemset(items=[u'whipped/sour-cream', u'whole-milk'], freq=317)
# FreqItemset(items=[u'oil'], freq=276)
# FreqItemset(items=[u'oil', u'other-vegetables'], freq=98)
# FreqItemset(items=[u'oil', u'root-vegetables'], freq=69)
# FreqItemset(items=[u'oil', u'whole-milk'], freq=111)
# FreqItemset(items=[u'pot-plants'], freq=170)
# FreqItemset(items=[u'house-keeping-products'], freq=82)
# FreqItemset(items=[u'tropical-fruit'], freq=1032)
# FreqItemset(items=[u'tropical-fruit', u'rolls/buns'], freq=242)
# FreqItemset(items=[u'tropical-fruit', u'rolls/buns', u'other-vegetables'], freq=77)
# FreqItemset(items=[u'tropical-fruit', u'rolls/buns', u'whole-milk'], freq=108)
# FreqItemset(items=[u'tropical-fruit', u'bottled-water'], freq=182)
# FreqItemset(items=[u'tropical-fruit', u'bottled-water', u'yogurt'], freq=70)
# FreqItemset(items=[u'tropical-fruit', u'bottled-water', u'whole-milk'], freq=79)
# FreqItemset(items=[u'tropical-fruit', u'yogurt'], freq=288)
# FreqItemset(items=[u'tropical-fruit', u'yogurt', u'rolls/buns'], freq=86)
# FreqItemset(items=[u'tropical-fruit', u'yogurt', u'other-vegetables'], freq=121)
# FreqItemset(items=[u'tropical-fruit', u'yogurt', u'other-vegetables', u'whole-milk'], freq=75)
# FreqItemset(items=[u'tropical-fruit', u'yogurt', u'whole-milk'], freq=149)
# FreqItemset(items=[u'tropical-fruit', u'other-vegetables'], freq=353)
# FreqItemset(items=[u'tropical-fruit', u'other-vegetables', u'whole-milk'], freq=168)
# FreqItemset(items=[u'tropical-fruit', u'soda'], freq=205)
# FreqItemset(items=[u'tropical-fruit', u'soda', u'other-vegetables'], freq=71)
# FreqItemset(items=[u'tropical-fruit', u'soda', u'whole-milk'], freq=77)
# FreqItemset(items=[u'tropical-fruit', u'root-vegetables'], freq=207)
# FreqItemset(items=[u'tropical-fruit', u'root-vegetables', u'yogurt'], freq=80)
# FreqItemset(items=[u'tropical-fruit', u'root-vegetables', u'other-vegetables'], freq=121)
# FreqItemset(items=[u'tropical-fruit', u'root-vegetables', u'other-vegetables', u'whole-milk'], freq=69)
# FreqItemset(items=[u'tropical-fruit', u'root-vegetables', u'whole-milk'], freq=118)
# FreqItemset(items=[u'tropical-fruit', u'whole-milk'], freq=416)
# FreqItemset(items=[u'sugar'], freq=333)
# FreqItemset(items=[u'sugar', u'rolls/buns'], freq=69)
# FreqItemset(items=[u'sugar', u'other-vegetables'], freq=106)
# FreqItemset(items=[u'sugar', u'soda'], freq=72)
# FreqItemset(items=[u'sugar', u'whole-milk'], freq=148)
# FreqItemset(items=[u'roll-products-'], freq=101)
# FreqItemset(items=[u'napkins'], freq=515)
# FreqItemset(items=[u'napkins', u'whipped/sour-cream'], freq=71)
# FreqItemset(items=[u'napkins', u'shopping-bags'], freq=71)
# FreqItemset(items=[u'napkins', u'citrus-fruit'], freq=75)
# FreqItemset(items=[u'napkins', u'rolls/buns'], freq=115)
# FreqItemset(items=[u'napkins', u'bottled-water'], freq=85)
# FreqItemset(items=[u'napkins', u'yogurt'], freq=121)
# FreqItemset(items=[u'napkins', u'tropical-fruit'], freq=99)
# FreqItemset(items=[u'napkins', u'pastry'], freq=69)
# FreqItemset(items=[u'napkins', u'other-vegetables'], freq=142)
# FreqItemset(items=[u'napkins', u'soda'], freq=118)
# FreqItemset(items=[u'napkins', u'root-vegetables'], freq=98)
# FreqItemset(items=[u'napkins', u'whole-milk'], freq=194)
# FreqItemset(items=[u'grapes'], freq=220)
# FreqItemset(items=[u'grapes', u'other-vegetables'], freq=89)
# FreqItemset(items=[u'grapes', u'whole-milk'], freq=72)
# FreqItemset(items=[u'soft-cheese'], freq=168)
# FreqItemset(items=[u'soft-cheese', u'other-vegetables'], freq=70)
# FreqItemset(items=[u'soft-cheese', u'whole-milk'], freq=74)
# FreqItemset(items=[u'shopping-bags'], freq=969)
# FreqItemset(items=[u'shopping-bags', u'rolls/buns'], freq=192)
# FreqItemset(items=[u'shopping-bags', u'bottled-water'], freq=108)
# FreqItemset(items=[u'shopping-bags', u'yogurt'], freq=150)
# FreqItemset(items=[u'shopping-bags', u'tropical-fruit'], freq=133)
# FreqItemset(items=[u'shopping-bags', u'other-vegetables'], freq=228)
# FreqItemset(items=[u'shopping-bags', u'other-vegetables', u'whole-milk'], freq=75)
# FreqItemset(items=[u'shopping-bags', u'soda'], freq=242)
# FreqItemset(items=[u'shopping-bags', u'root-vegetables'], freq=126)
# FreqItemset(items=[u'shopping-bags', u'whole-milk'], freq=241)
# FreqItemset(items=[u'turkey'], freq=80)
# FreqItemset(items=[u'UHT-milk'], freq=329)
# FreqItemset(items=[u'UHT-milk', u'bottled-water'], freq=72)
# FreqItemset(items=[u'UHT-milk', u'yogurt'], freq=73)
# FreqItemset(items=[u'UHT-milk', u'other-vegetables'], freq=80)
# FreqItemset(items=[u'UHT-milk', u'soda'], freq=75)
# FreqItemset(items=[u'chewing-gum'], freq=207)
# FreqItemset(items=[u'pet-care'], freq=93)
# FreqItemset(items=[u'chocolate'], freq=488)
# FreqItemset(items=[u'chocolate', u'shopping-bags'], freq=80)
# FreqItemset(items=[u'chocolate', u'rolls/buns'], freq=116)
# FreqItemset(items=[u'chocolate', u'yogurt'], freq=91)
# FreqItemset(items=[u'chocolate', u'tropical-fruit'], freq=80)
# FreqItemset(items=[u'chocolate', u'pastry'], freq=79)
# FreqItemset(items=[u'chocolate', u'other-vegetables'], freq=125)
# FreqItemset(items=[u'chocolate', u'soda'], freq=133)
# FreqItemset(items=[u'chocolate', u'whole-milk'], freq=164)
# FreqItemset(items=[u'cling-film/bags'], freq=112)
# FreqItemset(items=[u'brown-bread'], freq=638)
# FreqItemset(items=[u'brown-bread', u'shopping-bags'], freq=91)
# FreqItemset(items=[u'brown-bread', u'citrus-fruit'], freq=82)
# FreqItemset(items=[u'brown-bread', u'rolls/buns'], freq=124)
# FreqItemset(items=[u'brown-bread', u'bottled-water'], freq=81)
# FreqItemset(items=[u'brown-bread', u'newspapers'], freq=75)
# FreqItemset(items=[u'brown-bread', u'yogurt'], freq=143)
# FreqItemset(items=[u'brown-bread', u'yogurt', u'whole-milk'], freq=70)
# FreqItemset(items=[u'brown-bread', u'fruit/vegetable-juice'], freq=82)
# FreqItemset(items=[u'brown-bread', u'tropical-fruit'], freq=105)
# FreqItemset(items=[u'brown-bread', u'pastry'], freq=95)
# FreqItemset(items=[u'brown-bread', u'other-vegetables'], freq=184)
# FreqItemset(items=[u'brown-bread', u'other-vegetables', u'whole-milk'], freq=92)
# FreqItemset(items=[u'brown-bread', u'sausage'], freq=105)
# FreqItemset(items=[u'brown-bread', u'soda'], freq=124)
# FreqItemset(items=[u'brown-bread', u'pip-fruit'], freq=75)
# FreqItemset(items=[u'brown-bread', u'root-vegetables'], freq=100)
# FreqItemset(items=[u'brown-bread', u'whole-milk'], freq=248)
# FreqItemset(items=[u'butter-milk'], freq=275)
# FreqItemset(items=[u'butter-milk', u'rolls/buns'], freq=75)
# FreqItemset(items=[u'butter-milk', u'yogurt'], freq=84)
# FreqItemset(items=[u'butter-milk', u'other-vegetables'], freq=102)
# FreqItemset(items=[u'butter-milk', u'whole-milk'], freq=114)
# FreqItemset(items=[u'red/blush-wine'], freq=189)
# FreqItemset(items=[u'photo/film'], freq=91)
# FreqItemset(items=[u'frozen-vegetables'], freq=473)
# FreqItemset(items=[u'frozen-vegetables', u'whipped/sour-cream'], freq=78)
# FreqItemset(items=[u'frozen-vegetables', u'rolls/buns'], freq=100)
# FreqItemset(items=[u'frozen-vegetables', u'yogurt'], freq=122)
# FreqItemset(items=[u'frozen-vegetables', u'fruit/vegetable-juice'], freq=77)
# FreqItemset(items=[u'frozen-vegetables', u'tropical-fruit'], freq=86)
# FreqItemset(items=[u'frozen-vegetables', u'other-vegetables'], freq=175)
# FreqItemset(items=[u'frozen-vegetables', u'other-vegetables', u'whole-milk'], freq=95)
# FreqItemset(items=[u'frozen-vegetables', u'soda'], freq=85)
# FreqItemset(items=[u'frozen-vegetables', u'pip-fruit'], freq=72)
# FreqItemset(items=[u'frozen-vegetables', u'root-vegetables'], freq=114)
# FreqItemset(items=[u'frozen-vegetables', u'whole-milk'], freq=201)
# FreqItemset(items=[u'specialty-bar'], freq=269)
# FreqItemset(items=[u'specialty-bar', u'soda'], freq=71)
# FreqItemset(items=[u'spread-cheese'], freq=110)
# FreqItemset(items=[u'domestic-eggs'], freq=624)
# FreqItemset(items=[u'domestic-eggs', u'shopping-bags'], freq=89)
# FreqItemset(items=[u'domestic-eggs', u'whipped/sour-cream'], freq=98)
# FreqItemset(items=[u'domestic-eggs', u'citrus-fruit'], freq=102)
# FreqItemset(items=[u'domestic-eggs', u'rolls/buns'], freq=154)
# FreqItemset(items=[u'domestic-eggs', u'bottled-water'], freq=90)
# FreqItemset(items=[u'domestic-eggs', u'yogurt'], freq=141)
# FreqItemset(items=[u'domestic-eggs', u'yogurt', u'whole-milk'], freq=76)
# FreqItemset(items=[u'domestic-eggs', u'tropical-fruit'], freq=112)
# FreqItemset(items=[u'domestic-eggs', u'fruit/vegetable-juice'], freq=79)
# FreqItemset(items=[u'domestic-eggs', u'pastry'], freq=89)
# FreqItemset(items=[u'domestic-eggs', u'other-vegetables'], freq=219)
# FreqItemset(items=[u'domestic-eggs', u'other-vegetables', u'whole-milk'], freq=121)
# FreqItemset(items=[u'domestic-eggs', u'sausage'], freq=94)
# FreqItemset(items=[u'domestic-eggs', u'soda'], freq=122)
# FreqItemset(items=[u'domestic-eggs', u'pip-fruit'], freq=85)
# FreqItemset(items=[u'domestic-eggs', u'root-vegetables'], freq=141)
# FreqItemset(items=[u'domestic-eggs', u'root-vegetables', u'other-vegetables'], freq=72)
# FreqItemset(items=[u'domestic-eggs', u'root-vegetables', u'whole-milk'], freq=84)
# FreqItemset(items=[u'domestic-eggs', u'whole-milk'], freq=295)
# FreqItemset(items=[u'processed-cheese'], freq=163)
# FreqItemset(items=[u'processed-cheese', u'whole-milk'], freq=69)
# FreqItemset(items=[u'Instant-food-products'], freq=79)
# FreqItemset(items=[u'sausage'], freq=924)
# FreqItemset(items=[u'sausage', u'shopping-bags'], freq=154)
# FreqItemset(items=[u'sausage', u'rolls/buns'], freq=301)
# FreqItemset(items=[u'sausage', u'rolls/buns', u'other-vegetables'], freq=87)
# FreqItemset(items=[u'sausage', u'rolls/buns', u'whole-milk'], freq=92)
# FreqItemset(items=[u'sausage', u'bottled-water'], freq=118)
# FreqItemset(items=[u'sausage', u'yogurt'], freq=193)
# FreqItemset(items=[u'sausage', u'yogurt', u'other-vegetables'], freq=80)
# FreqItemset(items=[u'sausage', u'yogurt', u'whole-milk'], freq=86)
# FreqItemset(items=[u'sausage', u'tropical-fruit'], freq=137)
# FreqItemset(items=[u'sausage', u'tropical-fruit', u'whole-milk'], freq=71)
# FreqItemset(items=[u'sausage', u'other-vegetables'], freq=265)
# FreqItemset(items=[u'sausage', u'other-vegetables', u'whole-milk'], freq=100)
# FreqItemset(items=[u'sausage', u'soda'], freq=239)
# FreqItemset(items=[u'sausage', u'soda', u'rolls/buns'], freq=95)
# FreqItemset(items=[u'sausage', u'soda', u'other-vegetables'], freq=71)
# FreqItemset(items=[u'sausage', u'root-vegetables'], freq=147)
# FreqItemset(items=[u'sausage', u'root-vegetables', u'whole-milk'], freq=76)
# FreqItemset(items=[u'sausage', u'whole-milk'], freq=294)
# FreqItemset(items=[u'berries'], freq=327)
# FreqItemset(items=[u'berries', u'whipped/sour-cream'], freq=89)
# FreqItemset(items=[u'berries', u'yogurt'], freq=104)
# FreqItemset(items=[u'berries', u'other-vegetables'], freq=101)
# FreqItemset(items=[u'berries', u'soda'], freq=72)
# FreqItemset(items=[u'berries', u'whole-milk'], freq=116)

# %%
#Converting the results into a dataframe
dfp = pd.DataFrame(result)
dfp
# Out:
#                                             items  freq
# 0                                           [ham]   256
# 1                         [ham, other-vegetables]    90
# 2                               [ham, whole-milk]   113
# 3                                        [liquor]   109
# 4                                   [frankfurter]   580
# 5                    [frankfurter, shopping-bags]    81
# 6                       [frankfurter, rolls/buns]   189
# 7                    [frankfurter, bottled-water]    72
# 8                           [frankfurter, yogurt]   110
# 9                   [frankfurter, tropical-fruit]    93
# 10                          [frankfurter, pastry]    82
# 11                [frankfurter, other-vegetables]   162
# 12    [frankfurter, other-vegetables, whole-milk]    75
# 13                   [frankfurter, domestic-eggs]    69
# 14                     [frankfurter, brown-bread]    70
# 15                         [frankfurter, sausage]    99
# 16                            [frankfurter, soda]   111
# 17                       [frankfurter, pip-fruit]    71
# 18                 [frankfurter, root-vegetables]   100
# 19                      [frankfurter, whole-milk]   202
# 20                           [liquor-(appetizer)]    78
# 21                               [hamburger-meat]   327
# 22                   [hamburger-meat, rolls/buns]    85
# 23             [hamburger-meat, other-vegetables]   136
# 24                   [hamburger-meat, whole-milk]   145
# 25                                        [herbs]   160
# 26                      [herbs, other-vegetables]    76
# 27                       [herbs, root-vegetables]    69
# 28                            [herbs, whole-milk]    76
# 29                                       [pastry]   875
# ..                                            ...   ...
# 564  [domestic-eggs, root-vegetables, whole-milk]    84
# 565                   [domestic-eggs, whole-milk]   295
# 566                            [processed-cheese]   163
# 567                [processed-cheese, whole-milk]    69
# 568                       [Instant-food-products]    79
# 569                                     [sausage]   924
# 570                      [sausage, shopping-bags]   154
# 571                         [sausage, rolls/buns]   301
# 572       [sausage, rolls/buns, other-vegetables]    87
# 573             [sausage, rolls/buns, whole-milk]    92
# 574                      [sausage, bottled-water]   118
# 575                             [sausage, yogurt]   193
# 576           [sausage, yogurt, other-vegetables]    80
# 577                 [sausage, yogurt, whole-milk]    86
# 578                     [sausage, tropical-fruit]   137
# 579         [sausage, tropical-fruit, whole-milk]    71
# 580                   [sausage, other-vegetables]   265
# 581       [sausage, other-vegetables, whole-milk]   100
# 582                               [sausage, soda]   239
# 583                   [sausage, soda, rolls/buns]    95
# 584             [sausage, soda, other-vegetables]    71
# 585                    [sausage, root-vegetables]   147
# 586        [sausage, root-vegetables, whole-milk]    76
# 587                         [sausage, whole-milk]   294
# 588                                     [berries]   327
# 589                 [berries, whipped/sour-cream]    89
# 590                             [berries, yogurt]   104
# 591                   [berries, other-vegetables]   101
# 592                               [berries, soda]    72
# 593                         [berries, whole-milk]   116
#
# [594 rows x 2 columns]

# %%
#converting the frequencies to support

def floatsup(x, y):
    """
    Converts the frequency of a number to support by dividing it with the total no. of rows.
     Parameters
    -----------
    x: series of frequencies
    y: total no. of rows in a dataset.
    Returns
    ----------
    returns x/y
    
    """
    return float(x)/y

# %%
abc = new.count() #No of rows in a dataset
abc = float(abc)
abc
# Out:
# 9835.0

# %%
freq_ser =dfp['freq']
freq_ser_float = freq_ser.apply(floatsup, args=(abc,)) # method to convert to support

# %%
freq_ser_float
# Out:
# 0      0.026029
# 1      0.009151
# 2      0.011490
# 3      0.011083
# 4      0.058973
# 5      0.008236
# 6      0.019217
# 7      0.007321
# 8      0.011185
# 9      0.009456
# 10     0.008338
# 11     0.016472
# 12     0.007626
# 13     0.007016
# 14     0.007117
# 15     0.010066
# 16     0.011286
# 17     0.007219
# 18     0.010168
# 19     0.020539
# 20     0.007931
# 21     0.033249
# 22     0.008643
# 23     0.013828
# 24     0.014743
# 25     0.016268
# 26     0.007728
# 27     0.007016
# 28     0.007728
# 29     0.088968
#          ...
# 564    0.008541
# 565    0.029995
# 566    0.016573
# 567    0.007016
# 568    0.008033
# 569    0.093950
# 570    0.015658
# 571    0.030605
# 572    0.008846
# 573    0.009354
# 574    0.011998
# 575    0.019624
# 576    0.008134
# 577    0.008744
# 578    0.013930
# 579    0.007219
# 580    0.026945
# 581    0.010168
# 582    0.024301
# 583    0.009659
# 584    0.007219
# 585    0.014947
# 586    0.007728
# 587    0.029893
# 588    0.033249
# 589    0.009049
# 590    0.010574
# 591    0.010269
# 592    0.007321
# 593    0.011795
# Name: freq, Length: 594, dtype: float64

# %%
item_ser = dfp['items']

# %%
#creating a new dataframe 
dfp123 = pd.DataFrame()

# %%
dfp123
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
idx = 0

# %%
dfp123.insert(loc=idx, column='support', value=freq_ser_float)

# %%
dfp123.insert(loc=1, column='itemsets', value=item_ser)

# %%
dfp123
# Out:
#       support                                      itemsets
# 0    0.026029                                         [ham]
# 1    0.009151                       [ham, other-vegetables]
# 2    0.011490                             [ham, whole-milk]
# 3    0.011083                                      [liquor]
# 4    0.058973                                 [frankfurter]
# 5    0.008236                  [frankfurter, shopping-bags]
# 6    0.019217                     [frankfurter, rolls/buns]
# 7    0.007321                  [frankfurter, bottled-water]
# 8    0.011185                         [frankfurter, yogurt]
# 9    0.009456                 [frankfurter, tropical-fruit]
# 10   0.008338                         [frankfurter, pastry]
# 11   0.016472               [frankfurter, other-vegetables]
# 12   0.007626   [frankfurter, other-vegetables, whole-milk]
# 13   0.007016                  [frankfurter, domestic-eggs]
# 14   0.007117                    [frankfurter, brown-bread]
# 15   0.010066                        [frankfurter, sausage]
# 16   0.011286                           [frankfurter, soda]
# 17   0.007219                      [frankfurter, pip-fruit]
# 18   0.010168                [frankfurter, root-vegetables]
# 19   0.020539                     [frankfurter, whole-milk]
# 20   0.007931                          [liquor-(appetizer)]
# 21   0.033249                              [hamburger-meat]
# 22   0.008643                  [hamburger-meat, rolls/buns]
# 23   0.013828            [hamburger-meat, other-vegetables]
# 24   0.014743                  [hamburger-meat, whole-milk]
# 25   0.016268                                       [herbs]
# 26   0.007728                     [herbs, other-vegetables]
# 27   0.007016                      [herbs, root-vegetables]
# 28   0.007728                           [herbs, whole-milk]
# 29   0.088968                                      [pastry]
# ..        ...                                           ...
# 564  0.008541  [domestic-eggs, root-vegetables, whole-milk]
# 565  0.029995                   [domestic-eggs, whole-milk]
# 566  0.016573                            [processed-cheese]
# 567  0.007016                [processed-cheese, whole-milk]
# 568  0.008033                       [Instant-food-products]
# 569  0.093950                                     [sausage]
# 570  0.015658                      [sausage, shopping-bags]
# 571  0.030605                         [sausage, rolls/buns]
# 572  0.008846       [sausage, rolls/buns, other-vegetables]
# 573  0.009354             [sausage, rolls/buns, whole-milk]
# 574  0.011998                      [sausage, bottled-water]
# 575  0.019624                             [sausage, yogurt]
# 576  0.008134           [sausage, yogurt, other-vegetables]
# 577  0.008744                 [sausage, yogurt, whole-milk]
# 578  0.013930                     [sausage, tropical-fruit]
# 579  0.007219         [sausage, tropical-fruit, whole-milk]
# 580  0.026945                   [sausage, other-vegetables]
# 581  0.010168       [sausage, other-vegetables, whole-milk]
# 582  0.024301                               [sausage, soda]
# 583  0.009659                   [sausage, soda, rolls/buns]
# 584  0.007219             [sausage, soda, other-vegetables]
# 585  0.014947                    [sausage, root-vegetables]
# 586  0.007728        [sausage, root-vegetables, whole-milk]
# 587  0.029893                         [sausage, whole-milk]
# 588  0.033249                                     [berries]
# 589  0.009049                 [berries, whipped/sour-cream]
# 590  0.010574                             [berries, yogurt]
# 591  0.010269                   [berries, other-vegetables]
# 592  0.007321                               [berries, soda]
# 593  0.011795                         [berries, whole-milk]
#
# [594 rows x 2 columns]

# %% [markdown]
# ## 5. Calculation of different metrics:

# %%
def association_rules(df, metric="confidence", min_threshold=0.8):
    """Generates a DataFrame of association rules including the
    metrics 'score', 'confidence', and 'lift'
    Parameters
    -----------
    df : pandas DataFrame
      pandas DataFrame of frequent itemsets
      with columns ['support', 'itemsets']
    metric : string (default: 'confidence')
      Metric to evaluate if a rule is of interest.
      Supported metrics are 'support', 'confidence', 'lift'
      
      These metrics are computed as follows:
      - support(A->C) = support(A+C) [aka 'support'], range: [0, 1]
      - confidence(A->C) = support(A+C) / support(A), range: [0, 1]
      - lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
     
    min_threshold : float (default: 0.8)
      Minimal threshold for the evaluation metric
      to decide whether a candidate rule is of interest.
    Returns
    ----------
    pandas DataFrame with columns "antecedent support",
      "consequent support",
      "support", "confidence", "lift",
      
      of all rules for which
      metric(rule) >= min_threshold.
    """

    # check for mandatory columns
    if not all(col in df.columns for col in ["support", "itemsets"]):
        raise ValueError("Dataframe needs to contain the\
                         columns 'support' and 'itemsets'")

   
    # metrics for association rules
    metric_dict = {
        "antecedent support": lambda _, sA, __: sA,
        "consequent support": lambda _, __, sC: sC,
        "support": lambda sAC, _, __: sAC,
        "confidence": lambda sAC, sA, _: sAC/sA,
        "lift": lambda sAC, sA, sC: metric_dict["confidence"](sAC, sA, sC)/sC,
        }

    columns_ordered = ["antecedent support", "consequent support",
                       "support",
                       "confidence", "lift"]
                       

    # check for metric compliance
    if metric not in metric_dict.keys():
        raise ValueError("Metric must be 'confidence' or 'lift', got '{}'"
                         .format(metric))

    # get dict of {frequent itemset} -> support
    keys = df['itemsets'].values
    values = df['support'].values
    frozenset_vect = np.vectorize(lambda x: frozenset(x))
    frequent_items_dict = dict(zip(frozenset_vect(keys), values))

    # prepare buckets to collect frequent rules
    rule_antecedants = []
    rule_consequents = []
    rule_supports = []

    # iterate over all frequent itemsets
    for k in frequent_items_dict.keys():
        sAC = frequent_items_dict[k]
        # to find all possible combinations
        for idx in range(len(k)-1, 0, -1):
            # of antecedent and consequent
            for c in combinations(k, r=idx):
                antecedent = frozenset(c)
                consequent = k.difference(antecedent)
                sA = frequent_items_dict[antecedent]
                sC = frequent_items_dict[consequent]
                # check for the threshold
                if metric_dict[metric](sAC, sA, sC) >= min_threshold:
                    rule_antecedants.append(antecedent)
                    rule_consequents.append(consequent)
                    rule_supports.append([sAC, sA, sC])

    # check if frequent rule was generated
    if not rule_supports:
        return pd.DataFrame(
            columns=["antecedants", "consequents"] + columns_ordered)
    else:
        # generate metrics
        rule_supports = np.array(rule_supports).T.astype(float)
        sAC = rule_supports[0]
        sA = rule_supports[1]
        sC = rule_supports[2]
        df_res = pd.DataFrame(
            data=list(zip(rule_antecedants, rule_consequents)),
            columns=["antecedants", "consequents"])
        for m in columns_ordered:
            df_res[m] = metric_dict[m](sAC, sA, sC)

    return df_res

# %%
#generating association rules and metrics for those rules
rules = association_rules(dfp123, metric="support", min_threshold=0.007)

# %%
#displaying results
rules.head()
# Out:
#                       antecedants                     consequents  \
# 0           (whole-milk, chicken)              (other-vegetables)
# 1  (whole-milk, other-vegetables)                       (chicken)
# 2     (chicken, other-vegetables)                    (whole-milk)
# 3                    (whole-milk)     (chicken, other-vegetables)
# 4                       (chicken)  (whole-milk, other-vegetables)
#
#    antecedent support  consequent support   support  confidence      lift
# 0            0.017590            0.193493  0.008439    0.479769  2.479520
# 1            0.074835            0.042908  0.008439    0.112772  2.628223
# 2            0.017895            0.255516  0.008439    0.471591  1.845641
# 3            0.255516            0.017895  0.008439    0.033028  1.845641
# 4            0.042908            0.074835  0.008439    0.196682  2.628223
